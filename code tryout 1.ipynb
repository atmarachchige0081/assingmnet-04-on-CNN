# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the input shape of the images
input_shape = (64, 64, 3)

# Define the model architecture
model = models.Sequential()

# Convolutional layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten layer
model.add(layers.Flatten())

# Dense layers
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,306,435
# Trainable params: 1,306,435
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the input shape of the images
input_shape = (64, 64, 3)

# Define the model architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(3, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define the data generators
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/Train_Folder_out/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        '/Test_Folder_out/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical')

val_generator = val_datagen.flow_from_directory(
        '/Validation_Folder_out/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical')

# Train the model
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5', monitor='val_accuracy', save_best_only=True)
history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples/train_generator.batch_size,
        epochs=50,
        validation_data=val_generator,
        validation_steps=val_generator.samples/val_generator.batch_size,
        callbacks=[checkpoint])

# Evaluate the model on the test set
model.load_weights('best_model.h5')
scores = model.evaluate(test_generator, verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Found 1200 images belonging to 3 classes.
# Found 487 images belonging to 3 classes.
# Found 487 images belonging to 3 classes.
# Epoch 1/50
# 37/37 [==============================] - 14s 341ms/step - loss: 0.3360 - accuracy: 0.8400 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 2/50
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0176 - accuracy: 0.9958 - val_loss: 1.3614e-04 - val_accuracy: 1.0000
# Epoch 3/50
# 37/37 [==============================] - 5s 126ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.6184e-06 - val_accuracy: 1.0000
# Epoch 4/50
# 37/37 [==============================] - 5s 129ms/step - loss: 5.8992e-04 - accuracy: 1.0000 - val_loss: 8.3853e-06 - val_accuracy: 1.0000
# Epoch 5/50
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0493 - accuracy: 0.9867 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 6/50
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0115 - accuracy: 0.9975 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 7/50
# 37/37 [==============================] - 5s 126ms/step - loss: 5.0379e-04 - accuracy: 1.0000 - val_loss: 4.4101e-06 - val_accuracy: 1.0000
# Epoch 8/50
# 37/37 [==============================] - 5s 130ms/step - loss: 2.2742e-04 - accuracy: 1.0000 - val_loss: 1.8637e-06 - val_accuracy: 1.0000
# Epoch 9/50
# 37/37 [==============================] - 5s 127ms/step - loss: 6.0534e-05 - accuracy: 1.0000 - val_loss: 4.8051e-07 - val_accuracy: 1.0000
# Epoch 10/50
# 37/37 [==============================] - 5s 125ms/step - loss: 3.8729e-05 - accuracy: 1.0000 - val_loss: 5.0694e-07 - val_accuracy: 1.0000
# Epoch 11/50
# 37/37 [==============================] - 5s 127ms/step - loss: 5.3719e-05 - accuracy: 1.0000 - val_loss: 8.2613e-07 - val_accuracy: 1.0000
# Epoch 12/50
# 37/37 [==============================] - 5s 129ms/step - loss: 2.5767e-05 - accuracy: 1.0000 - val_loss: 9.2282e-07 - val_accuracy: 1.0000
# Epoch 13/50
# 37/37 [==============================] - 5s 127ms/step - loss: 6.6184e-05 - accuracy: 1.0000 - val_loss: 6.9224e-07 - val_accuracy: 1.0000
# Epoch 14/50
# 37/37 [==============================] - 5s 128ms/step - loss: 4.9762e-06 - accuracy: 1.0000 - val_loss: 2.8982e-07 - val_accuracy: 1.0000
# Epoch 15/50
# 37/37 [==============================] - 5s 132ms/step - loss: 4.6846e-06 - accuracy: 1.0000 - val_loss: 2.6877e-07 - val_accuracy: 1.0000
# Epoch 16/50
# 37/37 [==============================] - 5s 134ms/step - loss: 7.4624e-05 - accuracy: 1.0000 - val_loss: 2.4625e-07 - val_accuracy: 1.0000
# Epoch 17/50
# 37/37 [==============================] - 6s 153ms/step - loss: 3.8658e-05 - accuracy: 1.0000 - val_loss: 2.3646e-07 - val_accuracy: 1.0000
# Epoch 18/50
# 37/37 [==============================] - 5s 140ms/step - loss: 1.4397e-04 - accuracy: 1.0000 - val_loss: 3.1087e-08 - val_accuracy: 1.0000
# Epoch 19/50
# 37/37 [==============================] - 6s 149ms/step - loss: 1.1833e-04 - accuracy: 1.0000 - val_loss: 1.3708e-08 - val_accuracy: 1.0000
# Epoch 20/50
# 37/37 [==============================] - 6s 148ms/step - loss: 2.8628e-05 - accuracy: 1.0000 - val_loss: 1.0526e-08 - val_accuracy: 1.0000
# Epoch 21/50
# 37/37 [==============================] - 6s 147ms/step - loss: 1.4304e-05 - accuracy: 1.0000 - val_loss: 1.2817e-06 - val_accuracy: 1.0000
# Epoch 22/50
# 37/37 [==============================] - 5s 136ms/step - loss: 2.2500e-06 - accuracy: 1.0000 - val_loss: 1.8236e-07 - val_accuracy: 1.0000
# Epoch 23/50
# 37/37 [==============================] - 5s 140ms/step - loss: 3.8768e-05 - accuracy: 1.0000 - val_loss: 1.1260e-08 - val_accuracy: 1.0000
# Epoch 24/50
# 37/37 [==============================] - 6s 146ms/step - loss: 7.5213e-05 - accuracy: 1.0000 - val_loss: 1.2729e-08 - val_accuracy: 1.0000
# Epoch 25/50
# 37/37 [==============================] - 5s 146ms/step - loss: 4.3564e-05 - accuracy: 1.0000 - val_loss: 7.8331e-09 - val_accuracy: 1.0000
# Epoch 26/50
# 37/37 [==============================] - 5s 146ms/step - loss: 2.1379e-05 - accuracy: 1.0000 - val_loss: 1.0281e-08 - val_accuracy: 1.0000
# Epoch 27/50
# 37/37 [==============================] - 5s 143ms/step - loss: 1.5079e-05 - accuracy: 1.0000 - val_loss: 4.6509e-09 - val_accuracy: 1.0000
# Epoch 28/50
# 37/37 [==============================] - 5s 140ms/step - loss: 1.4185e-05 - accuracy: 1.0000 - val_loss: 9.7913e-10 - val_accuracy: 1.0000
# Epoch 29/50
# 37/37 [==============================] - 5s 139ms/step - loss: 6.8520e-06 - accuracy: 1.0000 - val_loss: 7.3435e-10 - val_accuracy: 1.0000
# Epoch 30/50
# 37/37 [==============================] - 5s 140ms/step - loss: 1.2875e-06 - accuracy: 1.0000 - val_loss: 4.8957e-10 - val_accuracy: 1.0000
# Epoch 31/50
# 37/37 [==============================] - 5s 138ms/step - loss: 2.8687e-06 - accuracy: 1.0000 - val_loss: 4.8957e-10 - val_accuracy: 1.0000
# Epoch 32/50
# 37/37 [==============================] - 5s 138ms/step - loss: 2.7427e-06 - accuracy: 1.0000 - val_loss: 4.8957e-10 - val_accuracy: 1.0000
# Epoch 33/50
# 37/37 [==============================] - 5s 137ms/step - loss: 2.8127e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 34/50
# 37/37 [==============================] - 5s 137ms/step - loss: 2.1302e-06 - accuracy: 1.0000 - val_loss: 2.4478e-10 - val_accuracy: 1.0000
# Epoch 35/50
# 37/37 [==============================] - 5s 137ms/step - loss: 4.2397e-07 - accuracy: 1.0000 - val_loss: 2.4478e-10 - val_accuracy: 1.0000
# Epoch 36/50
# 37/37 [==============================] - 5s 135ms/step - loss: 1.6833e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 37/50
# 37/37 [==============================] - 5s 138ms/step - loss: 2.2769e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 38/50
# 37/37 [==============================] - 5s 137ms/step - loss: 1.5825e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/50
# 37/37 [==============================] - 5s 138ms/step - loss: 3.1757e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 40/50
# 37/37 [==============================] - 5s 142ms/step - loss: 7.6455e-05 - accuracy: 1.0000 - val_loss: 3.4270e-09 - val_accuracy: 1.0000
# Epoch 41/50
# 37/37 [==============================] - 5s 143ms/step - loss: 1.9079e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 42/50
# 37/37 [==============================] - 5s 142ms/step - loss: 1.0914e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 43/50
# 37/37 [==============================] - 5s 136ms/step - loss: 1.4410e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 44/50
# 37/37 [==============================] - 5s 134ms/step - loss: 4.4140e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 45/50
# 37/37 [==============================] - 5s 135ms/step - loss: 4.3349e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 46/50
# 37/37 [==============================] - 5s 144ms/step - loss: 9.6901e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 47/50
# 37/37 [==============================] - 6s 159ms/step - loss: 2.1775e-04 - accuracy: 1.0000 - val_loss: 5.6300e-09 - val_accuracy: 1.0000
# Epoch 48/50
# 37/37 [==============================] - 6s 147ms/step - loss: 1.7962e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/50
# 37/37 [==============================] - 5s 145ms/step - loss: 1.3263e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/50
# 37/37 [==============================] - 5s 142ms/step - loss: 1.7959e-06 - accuracy: 1.0000 - val_loss: 1.2239e-09 - val_accuracy: 1.0000
# Test loss: 0.009911532513797283
# Test accuracy: 1.0

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the input shape of the images
input_shape = (64, 64, 3)

# Define the model architecture
model = models.Sequential()

# Convolutional layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten layer
model.add(layers.Flatten())

# Dense layers
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Define the batch size and number of epochs
batch_size = 32
epochs = 50

# Load the training, validation, and test data
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    '/Train_Folder_out/',
    target_size=(64, 64),
    batch_size=batch_size,
    class_mode='categorical')
    
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow_from_directory(
    '/Validation_Folder_out/',
    target_size=(64, 64),
    batch_size=batch_size,
    class_mode='categorical')

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    '/Test_Folder_out/',
    target_size=(64, 64),
    batch_size=batch_size,
    class_mode='categorical')

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator, verbose=2)
print('Test accuracy:', test_acc)

# Save the model
model.save('fruit_classification_model.h5')
# Out:
# Found 1200 images belonging to 3 classes.
# Found 487 images belonging to 3 classes.
# Found 487 images belonging to 3 classes.
# Epoch 1/50
# 37/37 [==============================] - 6s 133ms/step - loss: 0.3453 - accuracy: 0.8408 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 2/50
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.2062 - val_accuracy: 0.9250
# Epoch 3/50
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 1.5460e-04 - val_accuracy: 1.0000
# Epoch 4/50
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 4.1702e-05 - val_accuracy: 1.0000
# Epoch 5/50
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 8.9623e-05 - val_accuracy: 1.0000
# Epoch 6/50
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 2.4622e-04 - val_accuracy: 1.0000
# Epoch 7/50
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.7052e-06 - val_accuracy: 1.0000
# Epoch 8/50
# 37/37 [==============================] - 5s 147ms/step - loss: 2.0519e-04 - accuracy: 1.0000 - val_loss: 1.5398e-07 - val_accuracy: 1.0000
# Epoch 9/50
# 37/37 [==============================] - 6s 160ms/step - loss: 8.5984e-04 - accuracy: 0.9991 - val_loss: 9.5367e-08 - val_accuracy: 1.0000
# Epoch 10/50
# 37/37 [==============================] - 5s 142ms/step - loss: 6.7493e-05 - accuracy: 1.0000 - val_loss: 1.5994e-07 - val_accuracy: 1.0000
# Epoch 11/50
# 37/37 [==============================] - 5s 141ms/step - loss: 6.8689e-05 - accuracy: 1.0000 - val_loss: 6.3082e-08 - val_accuracy: 1.0000
# Epoch 12/50
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0013 - accuracy: 0.9991 - val_loss: 4.2205e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.8306e-06 - val_accuracy: 1.0000
# Epoch 14/50
# 37/37 [==============================] - 5s 143ms/step - loss: 2.4173e-04 - accuracy: 1.0000 - val_loss: 3.8743e-08 - val_accuracy: 1.0000
# Epoch 15/50
# 37/37 [==============================] - 6s 161ms/step - loss: 8.1893e-05 - accuracy: 1.0000 - val_loss: 8.4440e-09 - val_accuracy: 1.0000
# Epoch 16/50
# 37/37 [==============================] - 5s 142ms/step - loss: 2.3739e-04 - accuracy: 1.0000 - val_loss: 1.3361e-07 - val_accuracy: 1.0000
# Epoch 17/50
# 37/37 [==============================] - 6s 148ms/step - loss: 5.7781e-05 - accuracy: 1.0000 - val_loss: 3.8246e-08 - val_accuracy: 1.0000
# Epoch 18/50
# 37/37 [==============================] - 5s 145ms/step - loss: 1.3076e-05 - accuracy: 1.0000 - val_loss: 2.3345e-08 - val_accuracy: 1.0000
# Epoch 19/50
# 37/37 [==============================] - 5s 144ms/step - loss: 8.1829e-05 - accuracy: 1.0000 - val_loss: 2.7319e-09 - val_accuracy: 1.0000
# Epoch 20/50
# 37/37 [==============================] - 5s 142ms/step - loss: 9.1839e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 21/50
# 37/37 [==============================] - 5s 135ms/step - loss: 8.0086e-04 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 22/50
# 37/37 [==============================] - 5s 147ms/step - loss: 4.2091e-06 - accuracy: 1.0000 - val_loss: 4.9671e-10 - val_accuracy: 1.0000
# Epoch 23/50
# 37/37 [==============================] - 6s 161ms/step - loss: 1.6752e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 24/50
# 37/37 [==============================] - 6s 168ms/step - loss: 8.8694e-04 - accuracy: 1.0000 - val_loss: 3.2286e-09 - val_accuracy: 1.0000
# Epoch 25/50
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 4.8488e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 37/37 [==============================] - 6s 166ms/step - loss: 7.9815e-05 - accuracy: 1.0000 - val_loss: 2.9565e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 37/37 [==============================] - 7s 175ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 1.4608e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 37/37 [==============================] - 7s 179ms/step - loss: 4.5684e-04 - accuracy: 1.0000 - val_loss: 4.6690e-08 - val_accuracy: 1.0000
# Epoch 29/50
# 37/37 [==============================] - 8s 223ms/step - loss: 8.2018e-05 - accuracy: 1.0000 - val_loss: 4.9671e-10 - val_accuracy: 1.0000
# Epoch 30/50
# 37/37 [==============================] - 10s 259ms/step - loss: 2.6845e-05 - accuracy: 1.0000 - val_loss: 4.9671e-10 - val_accuracy: 1.0000
# Epoch 31/50
# 37/37 [==============================] - 7s 189ms/step - loss: 1.0647e-05 - accuracy: 1.0000 - val_loss: 4.9671e-10 - val_accuracy: 1.0000
# Epoch 32/50
# 37/37 [==============================] - 8s 206ms/step - loss: 2.4511e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 33/50
# 37/37 [==============================] - 7s 196ms/step - loss: 6.7763e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 34/50
# 37/37 [==============================] - 8s 203ms/step - loss: 7.0921e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 35/50
# 37/37 [==============================] - 7s 186ms/step - loss: 4.6594e-05 - accuracy: 1.0000 - val_loss: 7.4506e-10 - val_accuracy: 1.0000
# Epoch 36/50
# 37/37 [==============================] - 8s 205ms/step - loss: 1.9378e-06 - accuracy: 1.0000 - val_loss: 3.7253e-09 - val_accuracy: 1.0000
# Epoch 37/50
# 37/37 [==============================] - 7s 189ms/step - loss: 9.7416e-06 - accuracy: 1.0000 - val_loss: 1.7385e-09 - val_accuracy: 1.0000
# Epoch 38/50
# 37/37 [==============================] - 7s 191ms/step - loss: 1.4424e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/50
# 37/37 [==============================] - 7s 193ms/step - loss: 4.4569e-06 - accuracy: 1.0000 - val_loss: 4.4952e-08 - val_accuracy: 1.0000
# Epoch 40/50
# 37/37 [==============================] - 7s 181ms/step - loss: 5.2534e-05 - accuracy: 1.0000 - val_loss: 8.8413e-08 - val_accuracy: 1.0000
# Epoch 41/50
# 37/37 [==============================] - 7s 177ms/step - loss: 5.6381e-05 - accuracy: 1.0000 - val_loss: 2.0613e-08 - val_accuracy: 1.0000
# Epoch 42/50
# 37/37 [==============================] - 6s 173ms/step - loss: 1.9456e-05 - accuracy: 1.0000 - val_loss: 1.0928e-08 - val_accuracy: 1.0000
# Epoch 43/50
# 37/37 [==============================] - 6s 168ms/step - loss: 4.2250e-06 - accuracy: 1.0000 - val_loss: 6.9539e-09 - val_accuracy: 1.0000
# Epoch 44/50
# 37/37 [==============================] - 6s 163ms/step - loss: 4.0109e-06 - accuracy: 1.0000 - val_loss: 5.9605e-09 - val_accuracy: 1.0000
# Epoch 45/50
# 37/37 [==============================] - 6s 166ms/step - loss: 3.6388e-06 - accuracy: 1.0000 - val_loss: 5.2154e-09 - val_accuracy: 1.0000
# Epoch 46/50
# 37/37 [==============================] - 6s 164ms/step - loss: 2.7504e-05 - accuracy: 1.0000 - val_loss: 2.2352e-09 - val_accuracy: 1.0000
# Epoch 47/50
# 37/37 [==============================] - 6s 169ms/step - loss: 1.8239e-05 - accuracy: 1.0000 - val_loss: 2.4835e-10 - val_accuracy: 1.0000
# Epoch 48/50
# 37/37 [==============================] - 6s 171ms/step - loss: 6.8426e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/50
# 37/37 [==============================] - 6s 163ms/step - loss: 6.4011e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/50
# 37/37 [==============================] - 6s 162ms/step - loss: 3.1243e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# 16/16 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 925ms/epoch - 58ms/step
# Test accuracy: 1.0

# %%
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    directory="/Validation_Folder_out/",
    image_size=(64, 64),
    batch_size=32,
    shuffle=False
)
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(val_dataset)

# Print the validation accuracy
print("Validation accuracy:", val_accuracy)

# Make predictions on the validation set
val_predictions = model.predict(val_dataset)

# Convert the predicted probabilities to class labels
val_pred_labels = tf.argmax(val_predictions, axis=1)
val_true_labels = tf.concat([y for x, y in val_dataset], axis=0)

# Compute evaluation metrics
precision, recall, f1_score, _ = precision_recall_fscore_support(val_true_labels, val_pred_labels, average='macro')

# Print the evaluation metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)
# Out:
# Found 487 files belonging to 3 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       1 val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
#       2     directory="/Validation_Folder_out/",
#       3     image_size=(64, 64),
#       4     batch_size=32,
#       5     shuffle=False
#       6 )
#       7 # Evaluate the model on the validation set
# ----> 8 val_loss, val_accuracy = model.evaluate(val_dataset)
#      10 # Print the validation accuracy
#      11 print("Validation accuracy:", val_accuracy)
#
# File c:\Python39\cv\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File C:\Users\SUREKA~1\AppData\Local\Temp\__autograph_generated_file1kbrz_7s.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Python39\cv\Lib\site-packages\keras\engine\training.py", line 1852, in test_function  *
#         return step_function(self, iterator)
#     File "c:\Python39\cv\Lib\site-packages\keras\engine\training.py", line 1836, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Python39\cv\Lib\site-packages\keras\engine\training.py", line 1824, in run_step  **
#         outputs = model.test_step(data)
#     File "c:\Python39\cv\Lib\site-packages\keras\engine\training.py", line 1790, in test_step
#         self.compute_loss(x, y, y_pred, sample_weight)
#     File "c:\Python39\cv\Lib\site-packages\keras\engine\training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "c:\Python39\cv\Lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "c:\Python39\cv\Lib\site-packages\keras\losses.py", line 142, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "c:\Python39\cv\Lib\site-packages\keras\losses.py", line 268, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "c:\Python39\cv\Lib\site-packages\keras\losses.py", line 1984, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "c:\Python39\cv\Lib\site-packages\keras\backend.py", line 5559, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 3) are incompatible
